# %%
import pandas as pd
data=pd.read_csv("ai_job_dataset.csv")

# %%
data.head()
# Out:
#     job_id              job_title  salary_usd salary_currency  \
# 0  AI00001  AI Research Scientist       90376             USD
# 1  AI00002   AI Software Engineer       61895             USD
# 2  AI00003          AI Specialist      152626             USD
# 3  AI00004           NLP Engineer       80215             USD
# 4  AI00005          AI Consultant       54624             EUR
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
# 1               EN              CT           Canada            M
# 2               MI              FL      Switzerland            L
# 3               SE              FL            India            M
# 4               EN              PT           France            S
#
#   employee_residence  remote_ratio  \
# 0              China            50
# 1            Ireland           100
# 2        South Korea             0
# 3              India            50
# ...

# %%
data.shape
# Out:
# (15000, 19)

# %%
data.size
# Out:
# 285000

# %%
data.describe
# Out:
# <bound method NDFrame.describe of         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
# ...

# %%
data.columns
# Out:
# Index(['job_id', 'job_title', 'salary_usd', 'salary_currency',
#        'experience_level', 'employment_type', 'company_location',
#        'company_size', 'employee_residence', 'remote_ratio', 'required_skills',
#        'education_required', 'years_experience', 'industry', 'posting_date',
#        'application_deadline', 'job_description_length', 'benefits_score',
#        'company_name'],
#       dtype='object')

# %%
data.dtypes
# Out:
# job_id                     object
# job_title                  object
# salary_usd                  int64
# salary_currency            object
# experience_level           object
# employment_type            object
# company_location           object
# company_size               object
# employee_residence         object
# remote_ratio                int64
# required_skills            object
# education_required         object
# years_experience            int64
# industry                   object
# posting_date               object
# application_deadline       object
# job_description_length      int64
# benefits_score            float64
# company_name               object
# dtype: object

# %%
data.isnull()
# Out:
#        job_id  job_title  salary_usd  salary_currency  experience_level  \
# 0       False      False       False            False             False
# 1       False      False       False            False             False
# 2       False      False       False            False             False
# 3       False      False       False            False             False
# 4       False      False       False            False             False
# ...       ...        ...         ...              ...               ...
# 14995   False      False       False            False             False
# 14996   False      False       False            False             False
# 14997   False      False       False            False             False
# 14998   False      False       False            False             False
# 14999   False      False       False            False             False
#
#        employment_type  company_location  company_size  employee_residence  \
# ...

# %%
data["job_title"].nunique()
# Out:
# 20

# %%
data["job_title"].value_counts()
# Out:
# job_title
# Machine Learning Researcher    808
# AI Software Engineer           784
# Autonomous Systems Engineer    777
# Machine Learning Engineer      772
# AI Architect                   771
# Head of AI                     765
# NLP Engineer                   762
# Robotics Engineer              759
# Data Analyst                   759
# AI Research Scientist          756
# Data Engineer                  749
# AI Product Manager             743
# Research Scientist             742
# Principal Data Scientist       734
# AI Specialist                  728
# ML Ops Engineer                725
# Computer Vision Engineer       724
# Data Scientist                 720
# Deep Learning Engineer         718
# AI Consultant                  704
# Name: count, dtype: int64

# %%
data.head(2)
# Out:
#     job_id              job_title  salary_usd salary_currency  \
# 0  AI00001  AI Research Scientist       90376             USD
# 1  AI00002   AI Software Engineer       61895             USD
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
# 1               EN              CT           Canada            M
#
#   employee_residence  remote_ratio  \
# 0              China            50
# 1            Ireland           100
#
#                                    required_skills education_required  \
# 0         Tableau, PyTorch, Kubernetes, Linux, NLP           Bachelor
# 1  Deep Learning, AWS, Mathematics, Python, Docker             Master
#
#    years_experience    industry posting_date application_deadline  \
# 0                 9  Automotive   2024-10-18           2024-11-07
# 1                 1       Media   2024-11-20           2025-01-11
#
# ...

# %%
data["salary_currency"].nunique()
# Out:
# 3

# %%
data["salary_currency"]
# Out:
# 0        USD
# 1        USD
# 2        USD
# 3        USD
# 4        EUR
#         ...
# 14995    USD
# 14996    GBP
# 14997    USD
# 14998    EUR
# 14999    USD
# Name: salary_currency, Length: 15000, dtype: object

# %%
data.head(2)
# Out:
#     job_id              job_title  salary_usd salary_currency  \
# 0  AI00001  AI Research Scientist       90376             USD
# 1  AI00002   AI Software Engineer       61895             USD
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
# 1               EN              CT           Canada            M
#
#   employee_residence  remote_ratio  \
# 0              China            50
# 1            Ireland           100
#
#                                    required_skills education_required  \
# 0         Tableau, PyTorch, Kubernetes, Linux, NLP           Bachelor
# 1  Deep Learning, AWS, Mathematics, Python, Docker             Master
#
#    years_experience    industry posting_date application_deadline  \
# 0                 9  Automotive   2024-10-18           2024-11-07
# 1                 1       Media   2024-11-20           2025-01-11
#
# ...

# %%
data["company_location"].nunique()
# Out:
# 20

# %%
data[["company_location","job_title"]].value_counts()
# Out:
# company_location  job_title
# United Kingdom    AI Product Manager             58
# Japan             Machine Learning Researcher    58
# Germany           Head of AI                     58
# China             Autonomous Systems Engineer    57
# Denmark           AI Research Scientist          57
#                                                  ..
# Netherlands       AI Product Manager             25
# Austria           AI Consultant                  25
# Norway            Robotics Engineer              25
# United States     Computer Vision Engineer       24
# Norway            AI Product Manager             24
# Name: count, Length: 400, dtype: int64

# %%
data.head(2)
# Out:
#     job_id              job_title  salary_usd salary_currency  \
# 0  AI00001  AI Research Scientist       90376             USD
# 1  AI00002   AI Software Engineer       61895             USD
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
# 1               EN              CT           Canada            M
#
#   employee_residence  remote_ratio  \
# 0              China            50
# 1            Ireland           100
#
#                                    required_skills education_required  \
# 0         Tableau, PyTorch, Kubernetes, Linux, NLP           Bachelor
# 1  Deep Learning, AWS, Mathematics, Python, Docker             Master
#
#    years_experience    industry posting_date application_deadline  \
# 0                 9  Automotive   2024-10-18           2024-11-07
# 1                 1       Media   2024-11-20           2025-01-11
#
# ...

# %%
data["salary_usd"].mean()
# Out:
# np.float64(115348.96513333333)

# %%
data["salary_usd"].nlargest(10)
# Out:
# 9891     399095
# 2309     398084
# 12499    394917
# 12803    390292
# 317      388754
# 5483     383142
# 10468    381575
# 9637     379418
# 8377     372206
# 14431    371087
# Name: salary_usd, dtype: int64

# %%
data["salary_usd"].nsmallest(10)
# Out:
# 9549     32519
# 5974     32542
# 343      32587
# 8828     32666
# 10485    32692
# 8690     32790
# 10763    32907
# 846      32926
# 4749     32977
# 2633     33013
# Name: salary_usd, dtype: int64

# %%
data.head()
# Out:
#     job_id              job_title  salary_usd salary_currency  \
# 0  AI00001  AI Research Scientist       90376             USD
# 1  AI00002   AI Software Engineer       61895             USD
# 2  AI00003          AI Specialist      152626             USD
# 3  AI00004           NLP Engineer       80215             USD
# 4  AI00005          AI Consultant       54624             EUR
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
# 1               EN              CT           Canada            M
# 2               MI              FL      Switzerland            L
# 3               SE              FL            India            M
# 4               EN              PT           France            S
#
#   employee_residence  remote_ratio  \
# 0              China            50
# 1            Ireland           100
# 2        South Korea             0
# 3              India            50
# ...

# %%
data["experience_level"].value_counts()
# Out:
# experience_level
# MI    3781
# EX    3760
# SE    3741
# EN    3718
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,8))
plt.hist(data["salary_usd"],bins=30,color="orange",edgecolor="black")
plt.title("Salary Distribution")

plt.show()

# %%
data.groupby("job_title")["salary_usd"].mean()
# Out:
# job_title
# AI Architect                   117436.513619
# AI Consultant                  113671.870739
# AI Product Manager             114680.909825
# AI Research Scientist          117897.925926
# AI Software Engineer           114273.201531
# AI Specialist                  120570.758242
# Autonomous Systems Engineer    111396.557272
# Computer Vision Engineer       113472.707182
# Data Analyst                   111321.180501
# Data Engineer                  115970.720961
# Data Scientist                 115819.008333
# Deep Learning Engineer         113725.632312
# Head of AI                     118542.968627
# ML Ops Engineer                115431.335172
# Machine Learning Engineer      118827.919689
# Machine Learning Researcher    112621.747525
# NLP Engineer                   112670.937008
# Principal Data Scientist       116305.219346
# Research Scientist             116066.502695
# Robotics Engineer              116470.793149
# Name: salary_usd, dtype: float64

# %%
data.groupby("job_title")["salary_usd"].mean().nlargest(5)
# Out:
# job_title
# AI Specialist                120570.758242
# Machine Learning Engineer    118827.919689
# Head of AI                   118542.968627
# AI Research Scientist        117897.925926
# AI Architect                 117436.513619
# Name: salary_usd, dtype: float64

# %%
data.head(2)
# Out:
#     job_id              job_title  salary_usd salary_currency  \
# 0  AI00001  AI Research Scientist       90376             USD
# 1  AI00002   AI Software Engineer       61895             USD
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
# 1               EN              CT           Canada            M
#
#   employee_residence  remote_ratio  \
# 0              China            50
# 1            Ireland           100
#
#                                    required_skills education_required  \
# 0         Tableau, PyTorch, Kubernetes, Linux, NLP           Bachelor
# 1  Deep Learning, AWS, Mathematics, Python, Docker             Master
#
#    years_experience    industry posting_date application_deadline  \
# 0                 9  Automotive   2024-10-18           2024-11-07
# 1                 1       Media   2024-11-20           2025-01-11
#
# ...

# %%
data.groupby("company_location")["salary_usd"].mean().nlargest(5)
# Out:
# company_location
# Switzerland       170639.085791
# Denmark           165652.249357
# Norway            159490.533981
# United States     146833.045580
# United Kingdom    128720.186557
# Name: salary_usd, dtype: float64

# %%
data.groupby('remote_ratio')["salary_usd"].mean()
# Out:
# remote_ratio
# 0      114140.231133
# 50     115776.806793
# 100    116160.545935
# Name: salary_usd, dtype: float64

# %%
data.head(1)
# Out:
#     job_id              job_title  salary_usd salary_currency  \
# 0  AI00001  AI Research Scientist       90376             USD
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
#
#   employee_residence  remote_ratio                           required_skills  \
# 0              China            50  Tableau, PyTorch, Kubernetes, Linux, NLP
#
#   education_required  years_experience    industry posting_date  \
# 0           Bachelor                 9  Automotive   2024-10-18
#
#   application_deadline  job_description_length  benefits_score  \
# 0           2024-11-07                    1076             5.9
#
#       company_name
# 0  Smart Analytics

# %%
data.groupby("job_title")["salary_usd"].mean().nlargest(10)
# Out:
# job_title
# AI Specialist                120570.758242
# Machine Learning Engineer    118827.919689
# Head of AI                   118542.968627
# AI Research Scientist        117897.925926
# AI Architect                 117436.513619
# Robotics Engineer            116470.793149
# Principal Data Scientist     116305.219346
# Research Scientist           116066.502695
# Data Engineer                115970.720961
# Data Scientist               115819.008333
# Name: salary_usd, dtype: float64

# %%
plt.figure(figsize=(10,6))

plt.bar(data.groupby("job_title")["salary_usd"].mean().nlargest(10).keys(),data.groupby("job_title")["salary_usd"].mean().nlargest(10).values)
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))   # width=10 inches, height=6 inches

sns.boxplot(x='experience_level', y='salary_usd', data=data)
# Out:
# <Axes: xlabel='experience_level', ylabel='salary_usd'>

# %%
data.head(2)
# Out:
#     job_id              job_title  salary_usd salary_currency  \
# 0  AI00001  AI Research Scientist       90376             USD
# 1  AI00002   AI Software Engineer       61895             USD
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
# 1               EN              CT           Canada            M
#
#   employee_residence  remote_ratio  \
# 0              China            50
# 1            Ireland           100
#
#                                    required_skills education_required  \
# 0         Tableau, PyTorch, Kubernetes, Linux, NLP           Bachelor
# 1  Deep Learning, AWS, Mathematics, Python, Docker             Master
#
#    years_experience    industry posting_date application_deadline  \
# 0                 9  Automotive   2024-10-18           2024-11-07
# 1                 1       Media   2024-11-20           2025-01-11
#
# ...

# %%
data[data["job_title"]=="AI Software Engineer"]["salary_usd"].median()
# Out:
# np.float64(97701.5)

# %%
data.groupby('job_title')['salary_usd'].agg(['min','max'])
# Out:
#                                min     max
# job_title
# AI Architect                 33220  398084
# AI Consultant                33959  325757
# AI Product Manager           33770  381575
# AI Research Scientist        33092  394917
# AI Software Engineer         33013  379418
# AI Specialist                34174  390292
# Autonomous Systems Engineer  32790  364585
# Computer Vision Engineer     32519  366957
# Data Analyst                 32542  361541
# Data Engineer                33951  359044
# Data Scientist               32977  388754
# Deep Learning Engineer       32926  362503
# Head of AI                   32907  361718
# ML Ops Engineer              33056  352006
# Machine Learning Engineer    34286  344427
# Machine Learning Researcher  33114  399095
# NLP Engineer                 32587  357880
# Principal Data Scientist     33185  364635
# Research Scientist           34179  339526
# Robotics Engineer            32692  346789

# %%
data[data["job_title"]=="Data Analyst"].groupby("company_location")["salary_usd"].mean().nlargest()
# Out:
# company_location
# Denmark          174315.358974
# Switzerland      168107.257143
# Norway           151377.405405
# United States    141731.571429
# Singapore        133428.105263
# Name: salary_usd, dtype: float64

# %%
data["company_location"].value_counts()
# Out:
# company_location
# Germany           814
# Denmark           778
# Canada            769
# France            769
# Austria           765
# Singapore         764
# China             763
# India             754
# Sweden            752
# Israel            751
# Ireland           750
# Switzerland       746
# Japan             733
# Finland           733
# Australia         732
# Netherlands       731
# United Kingdom    729
# United States     724
# South Korea       722
# Norway            721
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14,8))
plt.bar(data["company_location"].value_counts().keys(),data["company_location"].value_counts())
plt.title("Countries by number of jobs")
plt.xticks(rotation=45, ha="right")

plt.show()

# %%
data["experience_level"].value_counts()
# Out:
# experience_level
# MI    3781
# EX    3760
# SE    3741
# EN    3718
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,8))
plt.title("Job Distribution by Experience Level")

plt.pie(data["experience_level"].value_counts(),autopct="%1.1f%%",labels=data["experience_level"].value_counts().index)
plt.show()

# %%
data.groupby("job_title")["salary_usd"].mean()
# Out:
# job_title
# AI Architect                   117436.513619
# AI Consultant                  113671.870739
# AI Product Manager             114680.909825
# AI Research Scientist          117897.925926
# AI Software Engineer           114273.201531
# AI Specialist                  120570.758242
# Autonomous Systems Engineer    111396.557272
# Computer Vision Engineer       113472.707182
# Data Analyst                   111321.180501
# Data Engineer                  115970.720961
# Data Scientist                 115819.008333
# Deep Learning Engineer         113725.632312
# Head of AI                     118542.968627
# ML Ops Engineer                115431.335172
# Machine Learning Engineer      118827.919689
# Machine Learning Researcher    112621.747525
# NLP Engineer                   112670.937008
# Principal Data Scientist       116305.219346
# Research Scientist             116066.502695
# Robotics Engineer              116470.793149
# Name: salary_usd, dtype: float64

# %%
plt.figure(figsize=(16,6))
plt.plot(data.groupby("job_title")["salary_usd"].mean())
plt.xticks(rotation=45, ha="right")

plt.title("Salary Trends by Job Title")
plt.xlabel("Job Title")
plt.ylabel("Average Salary (USD)")
plt.show()

# %%
 data.sort_values(["company_location", "salary_usd"], ascending=[True, False]).groupby("company_location").head(3)
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 7021   AI07022        AI Research Scientist      292604             USD
# 14251  AI14252  Machine Learning Researcher      292415             USD
# 3607   AI03608     Computer Vision Engineer      289765             USD
# 4584   AI04585              ML Ops Engineer      206978             USD
# 4189   AI04190            Robotics Engineer      206351             USD
# 5969   AI05970       Deep Learning Engineer      205534             USD
# 537    AI00538     Computer Vision Engineer      271344             USD
# 12693  AI12694                Data Engineer      271118             USD
# 9792   AI09793                AI Consultant      270550             USD
# 9890   AI09891                 NLP Engineer      204450             USD
# 12599  AI12600                 Data Analyst      203496             USD
# 10137  AI10138              ML Ops Engineer      201759             USD
# ...

# %%
data.head(1)
# Out:
#     job_id              job_title  salary_usd salary_currency  \
# 0  AI00001  AI Research Scientist       90376             USD
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
#
#   employee_residence  remote_ratio                           required_skills  \
# 0              China            50  Tableau, PyTorch, Kubernetes, Linux, NLP
#
#   education_required  years_experience    industry posting_date  \
# 0           Bachelor                 9  Automotive   2024-10-18
#
#   application_deadline  job_description_length  benefits_score  \
# 0           2024-11-07                    1076             5.9
#
#       company_name
# 0  Smart Analytics

# %%
data.groupby("company_location")["salary_usd"].median().loc[lambda x: x > data["salary_usd"].median()]
# Out:
# company_location
# Australia         103205.5
# Canada            100392.0
# Denmark           147504.5
# France            101908.0
# Germany           106923.0
# Netherlands       112202.0
# Norway            142386.0
# Singapore         115122.0
# Sweden            109435.0
# Switzerland       152901.0
# United Kingdom    115281.0
# United States     128606.0
# Name: salary_usd, dtype: float64
